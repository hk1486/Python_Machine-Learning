# %% [markdown]
# 공부시간, 과외시간과 성적 사이의 관계는 좌표로 나타냈을 때 좌표의 형태가 직선으로 해결되는 선형 회귀를 사용하기 적합했습니다. 공부 시간에 따른 점수가 아닌 합격 여부로 발표되는 시험이 있을 경우, 직선으로 해결하기에 적합하지 않습니다. 이 때 사용하는 로지스틱 회귀는 참과 거짓중에 하나를 내놓는 과정으로 참과 거짓을 구분한 "S"자를 눕혀놓은 형태의 선을 그어 주는 작업을 뜻합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sb
# %matplotlib inline
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
# 공부시간(x), 합격여부(y) => [공부시간, 합격여부]
data = [[2,0], [4,0], [6,0], [8,1], [10,1], [12,1], [14,1]]
xData = [i[0] for i in data]
yData = [i[1] for i in data]
print('공부시간 : {}, 합격여부 : {}'.format(xData, yData))
# Out:
# 공부시간 : [2, 4, 6, 8, 10, 12, 14], 합격여부 : [0, 0, 0, 1, 1, 1, 1]

# %%
a = tf.Variable(tf.random_normal([1], dtype=tf.float64))
b = tf.Variable(tf.random_normal([1], dtype=tf.float64))
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print('a = {}, b = {}'.format(sess.run(a), sess.run(b)))
# Out:
# a = [1.85641044], b = [-0.20589139]

# %%
# http://taewan.kim/post/sigmoid_diff  <- 시그모이드 방정식 설명참조 블로그
# np.e : 넘파이에서 지수 값(2.718281828459045)을 의미하는 상수
y = 1/(1+np.e ** -(a * xData + b))

# %%
# 시그모이드 방정식의 오차를 계산하는 수식을 만듭니다.
loss = -tf.reduce_mean(np.array(yData) * tf.log(y) + (1 - np.array(yData)) * tf.log(1-y))

# 오차를 최소로 하는 값을 찾습니다.
gradient_descent = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for i in range(3000001):
    sess.run(gradient_descent)
    if i % 5000 == 0:
        print('no : %4d, loss : %7.4f, 기울기 : %7.4f, y절편 : %7.4f' %(i, sess.run(loss), sess.run(a), sess.run(b)))
# Out:
# no :    0, loss :  1.4554, 기울기 :  0.5878, y절편 :  0.9917
# no : 5000, loss :  0.0585, 기울기 :  1.5527, y절편 : -10.6803
# no : 10000, loss :  0.0372, 기울기 :  2.0064, y절편 : -13.8787
# no : 15000, loss :  0.0275, 기울기 :  2.3157, y절편 : -16.0516
# no : 20000, loss :  0.0218, 기울기 :  2.5529, y절편 : -17.7166
# no : 25000, loss :  0.0180, 기울기 :  2.7458, y절편 : -19.0694
# no : 30000, loss :  0.0154, 기울기 :  2.9084, y절편 : -20.2090
# no : 35000, loss :  0.0134, 기울기 :  3.0488, y절편 : -21.1936
# no : 40000, loss :  0.0119, 기울기 :  3.1725, y절편 : -22.0601
# no : 45000, loss :  0.0106, 기울기 :  3.2829, y절편 : -22.8336
# no : 50000, loss :  0.0096, 기울기 :  3.3826, y절편 : -23.5320
# no : 55000, loss :  0.0088, 기울기 :  3.4735, y절편 : -24.1686
# no : 60000, loss :  0.0081, 기울기 :  3.5569, y절편 : -24.7533
# no : 65000, loss :  0.0075, 기울기 :  3.6341, y절편 : -25.2939
# no : 70000, loss :  0.0070, 기울기 :  3.7059, y절편 : -25.7965
# no : 75000, loss :  0.0066, 기울기 :  3.7729, y절편 : -26.2661
# ...
